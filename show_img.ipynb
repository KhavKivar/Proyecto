# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
img_path = '2k'
ext= 'jpg'

# %%
img_bw = np.loadtxt(img_path+'.dat') 
print(img_bw.shape)
plt.figure(figsize=(10,10))
plt.imshow(img_bw,cmap='gray')
# Out:
# (1440, 2560)

# %%
foutput = 'cpu_output.dat'


out = np.loadtxt(foutput)


plt.figure(figsize=(10,10))
plt.imshow(out,cmap='gray')

out = out/np.max(out)
thres = 0.02

out1 = np.where(out > thres, out ,1)

plt.figure(figsize=(10,10))
plt.imshow(out1,cmap='gray')
# Out:
# <ipython-input-6-5d079cc4a206>:10: RuntimeWarning: invalid value encountered in true_divide
#   out = out/np.max(out)
